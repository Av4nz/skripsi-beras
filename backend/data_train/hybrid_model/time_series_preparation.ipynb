# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
df = pd.read_csv('harga_beras_2021_2026.csv')

# %%
df
# Out:
#        tanggal  tahun  bulan  lebaran  harga_beras  harga_gkg  curah_hujan  \
# 0   2021-01-01   2021      1        0     11000.00    5317.84       357.44
# 1   2021-02-01   2021      2        0     11000.00    5319.55       667.13
# 2   2021-03-01   2021      3        0     11000.00    5213.95       217.58
# 3   2021-04-01   2021      4        0     10900.00    4882.22       173.56
# 4   2021-05-01   2021      5        1     10750.00    4944.18       130.15
# 5   2021-06-01   2021      6        0     10750.00    4963.86       186.10
# 6   2021-07-01   2021      7        0     10750.00    4873.89        21.88
# 7   2021-08-01   2021      8        0     10750.00    5038.23        78.86
# 8   2021-09-01   2021      9        0     10750.00    5047.91       166.60
# 9   2021-10-01   2021     10        0     10817.74    5015.92       146.03
# 10  2021-11-01   2021     11        0     10900.00    5060.46       377.97
# ...
